jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_40.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_54.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_241.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/12.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_269.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_68.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_296.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_83.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_97.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/107.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_282.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/463.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/339.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_123.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_137.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/265.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/271.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/259.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_309.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_308.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/258.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/264.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_136.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_122.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/338.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/462.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/476.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/106.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_96.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_283.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_297.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/112.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_82.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_69.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/13.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_55.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_240.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_254.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_41.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_57.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_43.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_256.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_281.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/104.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_94.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/110.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_80.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_295.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/138.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/306.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/460.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_134.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_120.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/299.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/266.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/267.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_109.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_121.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_135.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/449.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/475.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/461.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/139.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_81.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/111.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_294.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_280.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_95.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/105.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_42.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_257.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_243.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_56.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_73.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_266.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_272.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_67.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_299.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_98.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/108.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/120.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/478.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/322.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/450.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_138.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/281.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/256.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/242.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_312.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_306.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_307.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/243.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/280.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_105.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_111.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/294.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_139.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/445.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/323.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/135.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/109.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_99.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_298.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_273.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_66.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_72.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_267.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/34.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/20.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_58.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/36.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/22.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_64.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_271.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_265.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_70.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/137.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/123.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/309.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/453.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/335.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/321.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_107.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_113.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/269.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/241.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_305.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_311.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_310.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_304.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/254.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/240.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/297.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_112.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_106.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/283.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/452.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/308.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/136.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_71.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_65.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_270.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_258.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/23.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_59.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_61.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_260.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/33.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/27.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/132.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/330.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/456.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/442.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/287.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_116.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/293.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/244.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/250.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/278.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_314.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_315.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_301.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/251.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_117.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/292.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/286.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_103.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/443.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/325.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/480.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/127.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_48.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/32.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_249.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_74.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_275.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_60.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_263.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/18.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_76.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_62.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_277.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/24.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/125.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/131.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/augmented_image_89.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/119.jpg',
#  '/Users/kunal/Desktop/ML projects/dataset/without_mask/327.jpg',
#  ...]

# %% [markdown]
# ## Preprocessing Data

# %%
data = []
labels = []

for i in imagePaths:
    label = i.split(os.path.sep)[-2]
    labels.append(label)
    image = load_img(i, target_size = (224, 224))
    image = img_to_array(image)
    image = preprocess_input(image)
    data.append(image)

# %%
data

# %%
data = np.array(data, dtype = 'float32')
labels = np.array(labels)

# %%
data.shape

# %%
labels

# %%
lb = LabelBinarizer()
labels = lb.fit_transform(labels)
labels = to_categorical(labels)

# %%
labels

# %%
train_X, test_X, train_Y, test_Y = train_test_split(data, labels, test_size = 0.20, random_state = 10, stratify = labels)

# %%
aug = ImageDataGenerator(rotation_range=20, zoom_range= 0.15, width_shift_range= 0.2, shear_range= 0.15, horizontal_flip= True, vertical_flip= True, fill_mode='nearest')

# %%
baseModel = MobileNetV2(weights='imagenet', include_top=False, input_tensor= Input(shape = (224,224,3)))

# %%
baseModel.summary()

# %%
headModel = baseModel.output
headModel = AveragePooling2D(pool_size = (7,7))(headModel)
headModel = Flatten(name = 'Flatten')(headModel)
headModel = Dense(128, activation = 'relu')(headModel)
headModel = Dropout(0.5)(headModel)
headModel = Dense(2, activation = 'softmax')(headModel)

model = Model(inputs = baseModel.input, outputs = headModel)

# %%
for layer in baseModel.layers:
    layer.trainable = False

# %%
model.summary()

# %%
learning_rate = 0.001
Epochs = 20
batch_size = 12

opt = Adam(lr=learning_rate, decay = learning_rate/Epochs)

model.compile(loss = 'binary_crossentropy', optimizer = opt, metrics = ['accuracy'])

H = model.fit(
    aug.flow(train_X, train_Y, batch_size = batch_size),
    steps_per_epoch=len(train_X)//batch_size,
    validation_data=(test_X, test_Y),
    validation_steps=len(test_X)//batch_size,
    epochs = Epochs
)

model.save('mask.model')

# %%
predict = model.predict(test_X, batch_size=batch_size)
predict = np.argmax(predict, axis = 1)
print(classification_report(test_Y.argmax(axis=1), predict, target_names = lb.classes_))

# %%
model = load_model('mask.model')

# %%
model.summary()

# %% [markdown]
# # Test

# %%
prototxtPath = os.path.sep.join(['/Users/kunal/Desktop/ML projects/Face-Mask-Detection/deploy.prototxt'])
weightsPath = os.path.sep.join(['/Users/kunal/Desktop/ML projects/Face-Mask-Detection/res10_300x300_ssd_iter_140000.caffemodel'])

# %%
faceNet = cv.dnn.readNet(prototxtPath, weightsPath)

# %%
image.shape

# %%
def detect_mask(frame, faceNet, model):
    #Take dimensions to make blob
    (h,w) = frame.shape[:2]
    blob = cv.dnn.blobFromImage(frame, 1.0, (300,300), (104.0, 177.0, 123.0))
    
    faceNet.setInput(blob)
    detections = faceNet.forward()
    
    #initialise the list of faces, their correspondng locations and list of predictiob
    faces = []
    locs = []
    preds = []
    
    for i in range(0, detections.shape[2]):
        confidence = detections[0,0,i,2]
        
        if confidence > 0.5:
            #coordinates of x and y
            box = detections[0,0,i,3:7]*np.array([w,h,w,h])
            (startX, startY, endX, endY) = box.astype('int')
            
            #ensure the bounding boxes fall within the dimension of the frame
            (startX, startY) = (max(0, startX), max(0, startY))
            (endX, endY) = (min(w-1, endX), min(h-1, endY))
            
            #convert ROI from BGR to RGB channel, resize ut to 224, 224 and preprocess it
            face = frame[startY:endY, startX:endX]
            face = cv.cvtColor(face, cv.COLOR_BGR2RGB)
            face = cv.resize(face, (224, 224))
            face = img_to_array(face)
            face = preprocess_input(face)
            
            faces.append(face)
            locs.append((startX, startY, endX, endY))
            
            
        if len(faces)>0:
            faces = np.array(faces, dtype = 'float32')
            preds = model.predict(faces, batch_size = 12)
            
        return (locs, preds)

# %%
vs = VideoStream(src = 0).start()

while True:
    #resize the frames
    frame = vs.read()
    frane = imutils.resize(frame, width = 400)
    
    #detect faces and mask
    (locs, preds) = detect_mask(frame, faceNet, model)
    
    #loop over detected face 
    for (box, pred) in zip(locs, preds):
        (startX, startY, endX, endY) = box
        (mask, withoutMask) = pred
        
         #color and lobel of the bonding box and text
        label = 'Mask' if mask>withoutMask else 'No Mask'
        color = (0,255, 0) if label == 'Mask' else (0, 0, 255)
            
        #display the label and bonding boxes
        cv.putText(frame, label, (startX, startY-10), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
            
        cv.rectangle(frame,(startX, startY), (endX, endY), 2)
            
    cv.imshow('Frame', frame)
    key = cv.waitKey(1) & 0xFF
    
    if key ==ord('q'):
        break
    
cv.destroyAllWindows
vs.stop()
